# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
from sklearn import model_selection
from sklearn import linear_model
from sklearn import ensemble
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix, classification_report

# %matplotlib inline

# %%
# This is where I parse out text
def clean_soup(soup):
    for tag in soup.find_all(['script', 'style','meta']):
        tag.decompose()   
    return soup.get_text()


def find_between( s, first, last ):
    try:
        start = s.index( first ) + len( first )
        end = s.index( last, start )
        return s[start:end]
    except ValueError:
        return ""

# %%
import os

rootdir = '/home/roland/Workspace/Data/Procrastinating_HTML/'
data = pd.DataFrame(columns = ['activity', 'text', 'timestamp'])

URL_STRING = "__URL__: "
HTML_START = "<"
for subdir, dirs, files in os.walk(rootdir):
    i = 0
    for file in files:
        f = open(os.path.join(subdir, file))
        raw = f.read()
        url = ''
        
        if URL_STRING in raw:
            url = find_between(raw, URL_STRING, HTML_START)
            raw = raw.replace(url, '')
        
        # Below are character I am manually parsing out. There must exist a more efficient way to do this
        # but for now it runs fast enough.
        raw = raw.replace('\n', ' ')
        raw = raw.replace('\t', ' ')
        raw = raw.replace('\\n', ' ')
        raw = raw.replace('\\t', ' ')
        raw = raw.replace(URL_STRING, '')

        soup = BeautifulSoup(raw)
        data.set_value(i, 'text', clean_soup(soup))
        t = str(file).split('_')
        data.set_value(i, 'activity', t[0])
        timestamp = t[1].split('.')[0]
        data.set_value(i, 'timestamp', timestamp)
        data.set_value(i, 'url', url)
        i+=1
        f.close()
# Out:
# /home/roland/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /home/roland/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
data=data[data.text != ""]

# %%
data.timestamp = data.timestamp.str.replace("\(1\)","")
data.timestamp = data.timestamp.str.replace("T","-")

# %%
X = data[['text','url']]

X_train, X_test, y_train, y_test = model_selection.train_test_split(data, data.activity,test_size=0.33, random_state=43)

# %%
def evaluate_model(model, X_train = X_train, y_train = y_train, X_test = X_test, y_test = y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    accuracy = accuracy_score(y_test, y_pred)
    
    cm = confusion_matrix(y_test, y_pred)
    cr = classification_report(y_test, y_pred)
    
    print(cm)
    print(cr)
    
    return accuracy

# %% [markdown]
# ### Working with lemmatizing

# %%
# I am not using any of these libraries yet
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer
lemmatizer = WordNetLemmatizer()
stemmer = SnowballStemmer('english')

# %% [markdown]
# ### Below is model building

# %%
# replacing any empty urls with empty strings
data.url = data.url.str.replace('NA', "")

# %%
from sklearn.feature_extraction.text import CountVectorizer, HashingVectorizer, TfidfVectorizer

#instantiate our model, countvectorizing works th best
cvec = CountVectorizer(stop_words='english')

#fit the count vectorizer to the data. This 'teaches' the count vectorizer the dictionary.
#cvec.fit(data.text)

# %%
# # Vectorizing my text
# result_train = pd.DataFrame(data=cvec.transform(X_train.text).todense(), columns=cvec.vocabulary_)
# result_test = pd.DataFrame(data=cvec.transform(X_test.text).todense(), columns=cvec.vocabulary_)

# #NOTE TO SELF

# # Try using fuzzy matching on URLs. Try using the partial matching thing. Then label encode the ones that match well.

# %%
# Vectorizing my text
result_train = pd.DataFrame(data=cvec.fit_transform(X_train.text).todense(), columns = cvec.vocabulary_)
result_test = pd.DataFrame(data=cvec.transform(X_test.text).todense(), columns= cvec.vocabulary_)

#NOTE TO SELF

# Try using fuzzy matching on URLs. Try using the partial matching thing. Then label encode the ones that match well.

# %%
set(result_train.columns) - set(result_test.columns)
# Out:
# set()

# %% [markdown]
# #### Making my features here.
# I have my vectorized text which works really well, but there is additional informaiton that I can engineer that might be useful for prediction. Below is where I am going to work thourgh that process.

# %%
lm = linear_model.LogisticRegression()
rf = ensemble.RandomForestClassifier()
# fitting my training data  and scoring with my test data
lm.fit(result_train,y_train)
lm.score(result_test, y_test)
evaluate_model(lm, X_train=result_train, X_test=result_test)
# Out:
# [[175   6]
#  [  8 136]]
#              precision    recall  f1-score   support
#
#       procr       0.96      0.97      0.96       181
#        work       0.96      0.94      0.95       144
#
# avg / total       0.96      0.96      0.96       325
# 0.95692307692307688

# %%
predict = lm.predict(result_test)
actual = data.activity

# %%
coef = zip(result_test.columns, np.exp((lm.coef_[0])))

sorted(coef,key = lambda a: a[1], reverse=True)
# Out:
# [('123456789101112', 1.5030782244278027),
#  ('1805', 1.2236868646314289),
#  ('spacey', 1.1930074416362264),
#  ('csoulr666', 1.168849680627585),
#  ('61st', 1.1680991787213784),
#  ('background2instagram', 1.1609333818514178),
#  ('a3b0966', 1.1507351778717072),
#  ('corraaaal', 1.1307716488366686),
#  ('ucb', 1.1226528736040287),
#  ('dashboard290', 1.121188690551755),
#  ('usr', 1.1087638929433088),
#  ('murlocs', 1.1048573721045738),
#  ('braff', 1.1045683179905139),
#  ('tangotiger', 1.1016686272892013),
#  ('die4ever', 1.101661134620783),
#  ('startups', 1.1010777942707792),
#  ('bzzzzt', 1.1005131274527098),
#  ('callsabstract', 1.1000895079882986),
#  ('scripttext', 1.0963482960152977),
#  ('caprikel', 1.0943962275311907),
#  ('commentssharesavehidereport21101112game', 1.0936214569062455),
#  ('prisontattoos', 1.093039202962242),
#  ('lamprey', 1.092929885126964),
#  ('points5509', 1.0924658452006402),
#  ('hernandez', 1.0912919862497945),
#  ('0375829', 1.0894421819203137),
#  ('dmozspider', 1.0873318168549091),
#  ('brokencompass502', 1.0866241305602586),
#  ('cendeu', 1.0865894989882907),
#  ('cylon', 1.0862882335176736),
#  ('lazysmartdude', 1.0851074994726011),
#  ('359yankeespost', 1.0850463455763868),
#  ('shortcake2017', 1.0839727238826327),
#  ('wielding', 1.0830853796479107),
#  ('fantastic', 1.0815661953431677),
#  ('hxcpwnography', 1.0813141355548437),
#  ('dadameltdown', 1.0805068333249062),
#  ('contributorbobmcgee', 1.0803166529520687),
#  ('particolarmente', 1.079704991247761),
#  ('marinerssyenite', 1.0788635128038537),
#  ('imagecdn', 1.0784307434398734),
#  ('blackman', 1.0783681664870934),
#  ('haldron1988', 1.0780439323364495),
#  ('amelia', 1.0768036807256516),
#  ('913551', 1.0743259818385631),
#  ('kmc52', 1.0732095272076942),
#  ('0k27', 1.0730451783564792),
#  ('13271527162717', 1.0726797891101834),
#  ('itunes', 1.0726548790308743),
#  ('overheard', 1.0720691326737293),
#  ('yesmovementpart2', 1.0720620609290947),
#  ('snasa', 1.0716833499554212),
#  ('randomwe', 1.0716778163531155),
#  ('julelan', 1.0715293385569848),
#  ('points3208', 1.0714289334909923),
#  ('activity114711481149misleading', 1.0712616244201327),
#  ('stringrays191', 1.0707288051784147),
#  ('points7013', 1.0706491804107381),
#  ('6257', 1.0705505533626443),
#  ('sendcancelhow', 1.0704369365800381),
#  ('pythonnlpopen', 1.0703697212694074),
#  ('pitchforkemporium', 1.0701406111048279),
#  ('is_digit', 1.0689108676670687),
#  ('pyew', 1.0688226508592704),
#  ('fartswhenhappy', 1.0685740425386017),
#  ('8k10', 1.0680885910854332),
#  ('volantits', 1.067979385951539),
#  ('piston', 1.0672855491687634),
#  ('adabn', 1.0670381987619175),
#  ('wary', 1.0664285515026029),
#  ('redpilltipbot', 1.0664212293962003),
#  ('tiler', 1.0658242923507379),
#  ('kqj', 1.0658086947463095),
#  ('ferrari', 1.0655853674082334),
#  ('benficastvrap79', 1.0651330551076599),
#  ('falconsbocephuss', 1.0648662043187771),
#  ('cocky_fish', 1.0643039127873446),
#  ('surreal', 1.0636245472565797),
#  ('avvertenze', 1.0632598364246826),
#  ('grimtuesday', 1.062870281574323),
#  ('speculation', 1.0625788691613931),
#  ('complete', 1.0624761416254764),
#  ('points3645', 1.0622294468831108),
#  ('heidismiles', 1.0621251224765536),
#  ('shadowgate', 1.0619933215543613),
#  ('vocalist', 1.0615995314425819),
#  ('agojonathan', 1.0611652237093783),
#  ('mrmean0r', 1.0608219099089438),
#  ('colsample_bylevel', 1.0604875615905105),
#  ('degli', 1.060402381337441),
#  ('agentnebraska', 1.0599119232936096),
#  ('screenkey', 1.0597612468573536),
#  ('situ', 1.0596745977346509),
#  ('doc_samson', 1.059455990327197),
#  ('boldin', 1.0585235836132387),
#  ('bruiser', 1.0580306564365785),
#  ('points6553', 1.0578228032805819),
#  ('5322513580322266', 1.0574779343664704),
#  ('undercut', 1.0571217144627132),
#  ('massacre', 1.0570869812426293),
#  ('settingssettingsenter', 1.0567606612816236),
#  ('wes9523', 1.0567381334242267),
#  ('lf', 1.0563621196404445),
#  ('madriddarey297', 1.0562805248377303),
#  ('bottwitchclips2youtube', 1.0562270353503171),
#  ('mrthescientist', 1.0561835438328975),
#  ('señor', 1.0558853397977142),
#  ('kendall', 1.0555088729231539),
#  ('1656', 1.0553974296088693),
#  ('whizzer0', 1.0553325413517427),
#  ('afterpost', 1.0551615672947625),
#  ('idiotsfightingthings', 1.0546750800937843),
#  ('carbs', 1.054486306471291),
#  ('maxghost', 1.0543408065028224),
#  ('replace_keywords', 1.0541930457261215),
#  ('13567true', 1.0536015878044449),
#  ('imgrc', 1.0528935380888391),
#  ('hear', 1.0527524023224),
#  ('kt', 1.0526348264329668),
#  ('gaston', 1.0523307156056174),
#  ('redefines', 1.0519724021325165),
#  ('foodcreate', 1.0519107407463892),
#  ('brm', 1.0514793307727075),
#  ('pixel_fortune', 1.0514131293987106),
#  ('22m', 1.0502980412501493),
#  ('71st', 1.0502838838007245),
#  ('colonel_angus_', 1.0498992533952882),
#  ('applicarsi', 1.0488754122162443),
#  ('vinegarfingers', 1.0487885932307366),
#  ('boogaloo', 1.0479918547289497),
#  ('officialdeveloper', 1.0476367954665862),
#  ('deploying', 1.0475349967458549),
#  ('harvey', 1.0472420662020201),
#  ('30470', 1.0467886053955762),
#  ('pagina', 1.0461303405235756),
#  ('08t00', 1.0459115919797943),
#  ('20106610671068art', 1.0458739612617087),
#  ('dlbk03', 1.0455366983484506),
#  ('clockwise', 1.0455207211141067),
#  ('distracting', 1.0453844535840733),
#  ('mykhal', 1.045319699154313),
#  ('mitis', 1.0452688041578981),
#  ('086e', 1.0448527773193443),
#  ('dw_jb', 1.0447654882666753),
#  ('1631', 1.0447243178607173),
#  ('tehtrumpking', 1.0447002312081237),
#  ('goal81', 1.0446160963796531),
#  ('sirappleby', 1.0445706441478899),
#  ('emulators', 1.0443932009477497),
#  ('xenophon', 1.0442523556627343),
#  ('lannister32', 1.0441699297915508),
#  ('shredding', 1.0438838828028982),
#  ('components0is', 1.04381629521588),
#  ('zip132', 1.0436780065439801),
#  ('delboy1991', 1.0436737941365581),
#  ('mercys', 1.0436170873824184),
#  ('column_1_name', 1.0435758147293432),
#  ('version0what', 1.0435543833523793),
#  ('advisable', 1.0435157366291647),
#  ('375360', 1.0428423270329257),
#  ('x019', 1.0428339540464384),
#  ('faiths', 1.0427088076278839),
#  ('atoxhurgy', 1.0426062572777646),
#  ('cluelesspcventurer', 1.0424448052643662),
#  ('75991beat_the_benchmark', 1.0423442993886691),
#  ('1754143612', 1.0423429368110559),
#  ('giftingpantry', 1.0421242378385687),
#  ('ped', 1.0420926028901589),
#  ('nuke691', 1.0420613171652717),
#  ('climbed', 1.0420212902593962),
#  ('bendy', 1.0415664486464924),
#  ('overtop', 1.0413992903149594),
#  ('wftd', 1.04135566572565),
#  ('lesdoggg', 1.04135566572565),
#  ('btdownload', 1.04135566572565),
#  ('stroszek', 1.041325487198753),
#  ('points819', 1.0413241478854254),
#  ('406153', 1.0413043708973051),
#  ('deservedly', 1.0412030075500502),
#  ('xbh', 1.0409179856993238),
#  ('demario', 1.0407798591866546),
#  ('accidentallystoned', 1.0407098852443637),
#  ('ropadope', 1.0404797503951952),
#  ('midly', 1.0402619913589168),
#  ('thunderstom', 1.0400240616852081),
#  ('snobby', 1.039846118125312),
#  ('typewriters', 1.0394639360198556),
#  ('curvespost', 1.0392825345579633),
#  ('gators', 1.0392614008086061),
#  ('44pentagon', 1.0391419949793144),
#  ('85233342', 1.0390604965843799),
#  ('intelligentbacteria', 1.0389181016455082),
#  ('condizionate', 1.038838900258185),
#  ('dimwit', 1.0386035213515528),
#  ('motivation', 1.0383855933903674),
#  ('2483featured', 1.0379528068600312),
#  ('coo_matrix', 1.0378178326713432),
#  ('noahboah', 1.0377815474196996),
#  ('volibear', 1.0374758721577304),
#  ('find_duplicate_ip', 1.037378334486402),
#  ('partial', 1.0373721644831151),
#  ('commentssharesavehidereport9807880798080update', 1.0372994679847665),
#  ('inning7993', 1.037219385923877),
#  ('reticle', 1.0368851721160388),
#  ('warrents', 1.0366781934089044),
#  ('bobsacramanto', 1.03661837813392),
#  ('mahler35mjeff', 1.0365484914185876),
#  ('ginzo', 1.0364919146300002),
#  ('74dave', 1.0363764202083297),
#  ('arqade', 1.0363408923174073),
#  ('archconservative', 1.0363340201094198),
#  ('wrenagade419', 1.0363168926209876),
#  ('eichenwald', 1.0361081442721332),
#  ('flamewanker', 1.0360668547522645),
#  ('skagx', 1.0359580202890013),
#  ('chohan', 1.035811790112491),
#  ('13large', 1.0357626423266786),
#  ('isdigit', 1.035709005863076),
#  ('diss', 1.0354117986492948),
#  ('bc', 1.03529968808343),
#  ('replyview', 1.0352179080223249),
#  ('reachers', 1.0352022589656864),
#  ('yaypudding', 1.0351481261852988),
#  ('headcanon', 1.0351470540218413),
#  ('powers88756', 1.0350453584408903),
#  ('damage10', 1.0350217876588925),
#  ('fleek', 1.0349935039164275),
#  ('2239', 1.0349379331035293),
#  ('glitteratiaka', 1.0349087400776589),
#  ('cuervosoa', 1.0346877418645459),
#  ('jonatna', 1.0344107157922064),
#  ('tetsuooooooooooo', 1.034379358248031),
#  ('008438', 1.0343715170086856),
#  ('pintomp3', 1.0342703544051839),
#  ('tel', 1.0341621122904239),
#  ('honored', 1.0341495128215168),
#  ('unsureandwondering', 1.0341202930585029),
#  ('asayano_tangke', 1.0340921856771388),
#  ('follower_list', 1.0340768695943696),
#  ('guessing', 1.0339876344380678),
#  ('rouda', 1.0338544194310426),
#  ('images', 1.0338468519822472),
#  ('originsdraconic', 1.0338422381075476),
#  ('anita', 1.0337175666076968),
#  ('cage', 1.033685594257912),
#  ('derry', 1.0335836499106899),
#  ('linkslenovo', 1.0335620882162369),
#  ('minor_grid_line_alpha', 1.0335170488228367),
#  ('points3108', 1.0333971674952773),
#  ('translator', 1.0330242517894526),
#  ('services', 1.0330045672314014),
#  ('montages', 1.0326306017363018),
#  ('eirh', 1.0325547933215353),
#  ('1055', 1.0325419931212132),
#  ('squabbles', 1.0325387636530154),
#  ('rossthecolonel', 1.0325162208541978),
#  ('forges', 1.0324917878167907),
#  ('spazzword', 1.0324704924739845),
#  ('confide', 1.0322520446506676),
#  ('9994', 1.0321820686429577),
#  ('thelakeandtheglass', 1.0320602584543694),
#  ('ffirgriff', 1.0320175269052665),
#  ('vanquishing', 1.0318153789179534),
#  ('dadjokes_ss', 1.0316690142811931),
#  ('tersely', 1.0315974223109794),
#  ('h0twired', 1.0315478885311162),
#  ('personalfinancesort', 1.0315308350676475),
#  ('jessicabiel', 1.0315267266058443),
#  ('037', 1.0315143183242592),
#  ('jynxi', 1.0314197813028834),
#  ('paused', 1.0311911188868932),
#  ('406192', 1.0311307874544033),
#  ('provocative', 1.0309623255435358),
#  ('curds', 1.0308941383743579),
#  ('cristi1990an', 1.0305615799124772),
#  ('tutte', 1.0302616966502744),
#  ('points1514', 1.0302600457909195),
#  ('points1293', 1.0301637275098154),
#  ('takeonme', 1.0299496603309368),
#  ('25yo', 1.0298525396266307),
#  ('metabolite', 1.0296916620291496),
#  ('redeeming', 1.0296277770474418),
#  ('kgjeiok', 1.029597914246918),
#  ('later', 1.0295017460751426),
#  ('reactionscommentsharetop', 1.0294953919978693),
#  ('jwalla83', 1.0292875250776772),
#  ('wei', 1.0292610122216064),
#  ('points285', 1.0292606068907859),
#  ('points7995', 1.0290560392728867),
#  ('coltsamedema', 1.0289082620276988),
#  ('distribution', 1.0289067328086061),
#  ('yourvoice', 1.0288019563406789),
#  ('magicwhalesdoexist', 1.0287785485467495),
#  ('hatred', 1.0287539315515259),
#  ('hw', 1.0286852550531436),
#  ('filmed', 1.0286119540611003),
#  ('colleague', 1.0284213963642286),
#  ('heya', 1.0283886163669649),
#  ('facebooklike', 1.0283375431590991),
#  ('lineups', 1.0283034213035993),
#  ('termlimits', 1.0282610947848443),
#  ('nononono', 1.0282535905037367),
#  ('486', 1.0282472401329517),
#  ('koenig', 1.0281707709731982),
#  ('taspottsimport', 1.028151264732396),
#  ('ibeatyouoverthefence', 1.0280262073006505),
#  ('baratheons', 1.0279966602894146),
#  ('dolores', 1.0279896006175713),
#  ('annoying', 1.0279791203352919),
#  ('fcevertaku', 1.0278553243936244),
#  ('why_are_you_so_dumb_', 1.0278240295751979),
#  ('technology346', 1.0277490767891828),
#  ('my_research_account', 1.0277315673870615),
#  ('gof', 1.0275882930115412),
#  ('0kmoore', 1.027507920312396),
#  ('21st', 1.027501522666598),
#  ('mikzku', 1.027465693662504),
#  ('points4953', 1.0274474340602431),
#  ('gt250', 1.0274059719376891),
#  ('retrogam3rs', 1.0272997978453366),
#  ('niamh', 1.0272730237214054),
#  ('799', 1.0270175838534492),
#  ('topical', 1.0270152862963948),
#  ('illinois', 1.0269147418207993),
#  ('targaryen188', 1.0268139544142105),
#  ('superhuman', 1.0267950936265999),
#  ('1717', 1.0267652340035416),
#  ('amnesia', 1.0266909850561274),
#  ('8k11', 1.0266580634567757),
#  ('givemekarmaandstfu', 1.0264834860951662),
#  ('tabloid', 1.0264147846742944),
#  ('raa0927', 1.0262926210285011),
#  ('nmap', 1.0261916988862447),
#  ('personali', 1.0261872185233551),
#  ('m0repie', 1.0261646747781155),
#  ('kkehoe5', 1.0260825294485247),
#  ('dllhagycvvo', 1.0260677666860951),
#  ('offermans', 1.0260287190595723),
#  ('tools112', 1.0258133433441603),
#  ('mauling', 1.025792618432158),
#  ('pm_me_ur_fan_edits', 1.0257341406815152),
#  ('mkho11', 1.025547870376861),
#  ('1357660070890', 1.0255362189622015),
#  ('perkins', 1.025300401606104),
#  ('symp', 1.0252643074742069),
#  ('pleonasm', 1.0252008348842285),
#  ('my_kinky_alt', 1.0251449555766619),
#  ('liambacca', 1.0250528090484587),
#  ('studentized', 1.0250022300733983),
#  ('dimenticato', 1.0249832369194667),
#  ('heavily', 1.0249686018574464),
#  ('fuelphp', 1.0249460083548809),
#  ('yaknow', 1.0248974381447955),
#  ('shadowcaster', 1.0247930017686113),
#  ('phoxxent', 1.0247552205493999),
#  ('barba', 1.0247456761302229),
#  ('shirtslook', 1.0247456761302229),
#  ('73rd', 1.0247142105068792),
#  ('thea', 1.0246626766307281),
#  ('tfordp', 1.0246062187312925),
#  ('2090', 1.0245381794791599),
#  ('2240725', 1.0244557088822428),
#  ('upliketrump', 1.0244533811627037),
#  ('ved', 1.0244411177746631),
#  ('zo', 1.0242535907628347),
#  ('lightbulb', 1.0240311425899589),
#  ('metsmazzocchi', 1.0239043470191984),
#  ('manman778', 1.0238287374536303),
#  ('judas1878', 1.0237790989612343),
#  ('yoguy2', 1.0237018477599313),
#  ('freeman', 1.0237018477599313),
#  ('psychedelic', 1.02363979286041),
#  ('helpabout', 1.0236331501941078),
#  ('psychometrics', 1.0235664823981987),
#  ('underused', 1.0235186437951869),
#  ('npr', 1.0234728216200231),
#  ('palacenamelock12', 1.0233849637420325),
#  ('mrthirsty15', 1.0232376992810124),
#  ('feliz', 1.0231675111778817),
#  ('restperformance', 1.023100351481294),
#  ('noble', 1.023098023579162),
#  ('xlinkedx', 1.0230572783872935),
#  ('sensory', 1.02300358510462),
#  ('4071637', 1.0229757009679508),
#  ('htmcachedsimilarlinear', 1.0228461072662502),
#  ('lecture', 1.0228407720632668),
#  ('readers30', 1.022769246100715),
#  ('sayf_al_din', 1.0227532493480784),
#  ('dist', 1.0226615456414143),
#  ('51268', 1.0226561372878424),
#  ('zero', 1.0226431955264177),
#  ('unitedgh0stdylan', 1.0225855013482454),
#  ('postsapr', 1.0224949279751778),
#  ('peregrine', 1.0224259177047388),
#  ('floatingcats', 1.02232775378133),
#  ('anoutherplague', 1.0223109420707719),
#  ('formalchemy', 1.0222799507062679),
#  ('ovr', 1.0222212796711851),
#  ('5ktil', 1.022176195858977),
#  ('maedar', 1.022134067869082),
#  ('goldmanlast', 1.0221007855053719),
#  ('jackattack729', 1.0220517316350646),
#  ('gini', 1.0218828265745887),
#  ('portraits', 1.0218792115392892),
#  ('tarly', 1.0218484742651812),
#  ('underestimated', 1.0218098840088019),
#  ('individual_throwaway', 1.0218095656094823),
#  ('konekotoujou', 1.0217904983914163),
#  ('disposition', 1.021657926997253),
#  ('gimick', 1.0216165227485339),
#  ('3parkbenchhydra', 1.0215935176338677),
#  ('downer', 1.0215895315915688),
#  ('yielding', 1.0215531561792732),
#  ('rikustar', 1.0214454990759543),
#  ('crafts', 1.0214111700393835),
#  ('hun', 1.0213635763765867),
#  ('ohazulike', 1.0213204338927244),
#  ('pita', 1.0212861513773652),
#  ('ron', 1.0212571892356654),
#  ('commentsnewsunique', 1.0212017821713126),
#  ('47108547995356098', 1.0211702881800275),
#  ('list2', 1.021128761705107),
#  ('wtfduud', 1.0210801508368046),
#  ('8782920', 1.0209165428041314),
#  ('277771', 1.0208061441091176),
#  ('gummy4631', 1.0207992271110511),
#  ('minimock', 1.0207617188727571),
#  ('hatcher', 1.020721845870191),
#  ('masteries', 1.0207124345322045),
#  ('krbv', 1.0207075552107741),
#  ('logistic', 1.0206904132355106),
#  ('settings0chrome', 1.0206740409712485),
#  ('solar_eclipse_of_may_10', 1.0205983562568877),
#  ('district', 1.0205813043298666),
#  ('drunkstarcraft', 1.0205489375260886),
#  ('requestssee', 1.0205382405612371),
#  ('cheatum', 1.0204972586647385),
#  ('shortcuts', 1.0204740452003347),
#  ('sheet', 1.0204683560628669),
#  ('bsd', 1.0204683560628669),
#  ('arbor', 1.0203846167289694),
#  ('zer0w0rries', 1.0203773327956731),
#  ('679', 1.0203651027989951),
#  ('impersonated', 1.0203294305665367),
#  ('rotoworld', 1.0203246231600693),
#  ('agohodor', 1.0202564423979701),
#  ('floralcookies', 1.0202312674515435),
#  ('nozhaxbl', 1.0202308334446741),
#  ('surging', 1.020210105110908),
#  ('righthandonly', 1.0201901881043598),
#  ('chan1', 1.0201755267384611),
#  ('steelersa_smitty56', 1.0201288683670269),
#  ('opie', 1.0200534854633758),
#  ('the_donald299', 1.0199187834891947),
#  ('kirkwood', 1.0198925226106448),
#  ('iterable0python', 1.0198806125927049),
#  ('felled', 1.0198406338029185),
#  ('economies', 1.0198252409844752),
#  ('dare2beeevil', 1.0198156651586208),
#  ('pseudotensor', 1.0197332053937123),
#  ('samuelslast', 1.0197307202938852),
#  ('bumgarner', 1.0196605811781396),
#  ('406122', 1.0196102271742784),
#  ('evisceration', 1.0195511468267591),
#  ('isisrespecter_69', 1.0195104744448851),
#  ('azai', 1.0194804706659537),
#  ('boobailey808', 1.0194614673732483),
#  ('htmlcachedsimilarbut', 1.019456029936842),
#  ('danjoy1972', 1.0194220629598649),
#  ('32152257', 1.0194182215657916),
#  ('mls_2_san_diego', 1.0193821993100014),
#  ('meddlingtrump', 1.0193780193569464),
#  ('assured', 1.0193411287347185),
#  ('6596061art', 1.0193151127132245),
#  ('complied', 1.0190516708281989),
#  ('expendable', 1.0190119063652039),
#  ('iniparse', 1.0189460676343889),
#  ('readers161', 1.0188969563553927),
#  ('swallowing', 1.0188883254140149),
#  ('distrumpia', 1.0188658550388139),
#  ('create_default_context', 1.0188270607477461),
#  ('special', 1.0187672427797403),
#  ('cloudflare', 1.0187642890327202),
#  ('learningartificial', 1.0187167053769981),
#  ('dudewithagun', 1.0186853651538068),
#  ('wealthy', 1.0186463022613055),
#  ('gong', 1.0186116170673847),
#  ('woodwork', 1.0185921800592184),
#  ('domination', 1.0185904032419024),
#  ('dashboard626', 1.0185566899155463),
#  ('gomer', 1.0184676609797616),
#  ('surprises', 1.0184346182021644),
#  ('apartyinmypants', 1.018424510517747),
#  ('yankeedude252', 1.0183926154453851),
#  ('afferent_input', 1.0183149875786972),
#  ('2579', 1.0182752922026674),
#  ('h3h3', 1.0181879013721746),
#  ('dengode', 1.0181768264214384),
#  ('388astrospost', 1.0181666731759713),
#  ('atrocity', 1.018163118812377),
#  ('bebeboombox', 1.0181294309803586),
#  ('tyrod', 1.0180874619031288),
#  ('3507', 1.0180295565369217),
#  ('practices', 1.0180265806098383),
#  ('88111223', 1.0180211826767749),
#  ('entanglements', 1.0179791205359729),
#  ('scmsupersterling', 1.0178713023286325),
#  ('commentshe', 1.0178451422571355),
#  ('1598', 1.0177932871175144),
#  ('geologist', 1.0177901946149033),
#  ('antigravity21', 1.0177875369071978),
#  ('nosuparker', 1.0177071947015717),
#  ('d5ad74e', 1.0176702798299204),
#  ('contain', 1.0176648846795968),
#  ('itsnotthenetwork', 1.0176454487131059),
#  ('531edge', 1.0176270165364805),
#  ('simulate', 1.0175486790271353),
#  ('621121', 1.0175466581129582),
#  ('fony', 1.0174946639893856),
#  ('idiotmonkey12', 1.0174869945657332),
#  ('quantregresults', 1.017455809607859),
#  ('sanguinepar', 1.0174299934413134),
#  ('bbtn', 1.0174246317832067),
#  ('ispeelmydrink', 1.0174222949126379),
#  ('frontal', 1.0173794306585677),
#  ('grandchildren', 1.0173245935570883),
#  ('weather_stn1', 1.0173087975224202),
#  ('shivhanna', 1.017306140135618),
#  ('pierresderriere', 1.0172699745175848),
#  ('chemicals', 1.0172664041683357),
#  ('_delt', 1.017264165140715),
#  ('bleaker', 1.0172531069229775),
#  ('thewaywewere', 1.0172212712493016),
#  ('2591011had', 1.017200348713448),
#  ('pitied', 1.0171962671018184),
#  ('invader', 1.0171742447934713),
#  ('movies1043', 1.0171142735470846),
#  ('domesin', 1.0171103548130029),
#  ('visceral', 1.0170874856503571),
#  ('samplesubmission', 1.0170870703529189),
#  ('fill_in_missing_dates', 1.0170811861096394),
#  ('skimping', 1.0170583882312483),
#  ('readers74', 1.0170389283518129),
#  ('codeweavercw', 1.0170281991898624),
#  ('kemporium', 1.0169891861105795),
#  ('paultmanteau', 1.0169743956794126),
#  ('shortcutmoreshoppingwalletfinancedocsbooksbloggercontactshangoutskeepclassroomeven',
#   1.016949143620399),
#  ('89corinne', 1.0169316200220329),
#  ('repetitions', 1.0169167308926021),
#  ('awfulness', 1.0168164719864241),
#  ('suomi', 1.0167991573999642),
#  ('stretch_both', 1.0167991573999642),
#  ('points1531', 1.0167991573999642),
#  ('necessarily', 1.0167991573999642),
#  ('erogaki', 1.0167991573999642),
#  ('272', 1.0167991573999642),
#  ('icv2', 1.0167991573999642),
#  ('slims', 1.0167991573999642),
#  ('song', 1.0167991573999642),
#  ('thatoneguy0101', 1.0167991573999642),
#  ('lightbringer', 1.0167991573999642),
#  ('physical', 1.0167991573999642),
#  ('state', 1.0167991573999642),
#  ('lend', 1.0167991573999642),
#  ('lindsay', 1.0167991573999642),
#  ('whiten', 1.0167991573999642),
#  ('slammed', 1.0167991573999642),
#  ('misrepresentation', 1.0167991573999642),
#  ('list_names', 1.0167991573999642),
#  ('bard', 1.0167991573999642),
#  ('statistical', 1.0167991573999642),
#  ('goal', 1.0167991573999642),
#  ('trudy', 1.0167991573999642),
#  ('903', 1.0167991573999642),
#  ('skew', 1.0167991573999642),
#  ('yule_walker', 1.0167991573999642),
#  ('helps', 1.0167991573999642),
#  ('explainlikeimfive', 1.0167991573999642),
#  ('countries', 1.0167991573999642),
#  ('gameofthrones449', 1.0167991573999642),
#  ('aws', 1.0167991573999642),
#  ('bug', 1.0167991573999642),
#  ('bevel', 1.0167991573999642),
#  ('subplots_adjust', 1.0167991573999642),
#  ('optimal', 1.0167991573999642),
#  ('readableprogramming', 1.0167991573999642),
#  ('harder', 1.0167991573999642),
#  ('ridge', 1.0167991573999642),
#  ('tremor', 1.0167991573999642),
#  ('passage', 1.0167991573999642),
#  ('seldom', 1.0167991573999642),
#  ('modifier', 1.0167991573999642),
#  ('achieved', 1.0167991573999642),
#  ('invisible', 1.0167991573999642),
#  ('reduced', 1.0167991573999642),
#  ('rayne37', 1.0167991573999642),
#  ('moccafixgold', 1.0167991573999642),
#  ('cmubigguy', 1.0167991573999642),
#  ('puppet', 1.0167991573999642),
#  ('cavalry', 1.0167991573999642),
#  ('lu', 1.0167991573999642),
#  ('lapping', 1.0167991573999642),
#  ('contingency', 1.0167991573999642),
#  ('nivlacsupreme', 1.0167991573999642),
#  ('waitingget', 1.0167991573999642),
#  ('boltons', 1.0167991573999642),
#  ('points8289', 1.0167991573999642),
#  ('paolo', 1.0167991573999642),
#  ('2048', 1.0167991573999642),
#  ('mapdata_copyright_op', 1.0167991573999642),
#  ('drill', 1.0167991573999642),
#  ('permitting', 1.0167991573999642),
#  ('shortages', 1.0167991573999642),
#  ('12345678910111213141516171819202122232425262728293031323334353637383940414243',
#   1.0167991573999642),
#  ('bronx', 1.0167991573999642),
#  ('alopecia', 1.0167991573999642),
#  ('sloppily', 1.0167991573999642),
#  ('4519', 1.0167991573999642),
#  ('1027', 1.0167991573999642),
#  ('kallously', 1.0167991573999642),
#  ('starzephon', 1.0167991573999642),
#  ('intriguied', 1.0167991573999642),
#  ('cxrabc', 1.0167991573999642),
#  ('senate2675', 1.0167991573999642),
#  ('points2676', 1.0167991573999642),
#  ('points2677', 1.0167991573999642),
#  ('6009', 1.0167991573999642),
#  ('wanwiththehighground', 1.0167991573999642),
#  ('collisions', 1.0167991573999642),
#  ('realities', 1.0167991573999642),
#  ('carolyn', 1.0167991573999642),
#  ('twixter', 1.0167991573999642),
#  ('goddamnit', 1.0167991573999642),
#  ('lackadaisical', 1.0167991573999642),
#  ('imrunninglow', 1.0167991573999642),
#  ('942016', 1.0167991573999642),
#  ('meetingspost', 1.0167991573999642),
#  ('333athleticspost', 1.0167991573999642),
#  ('398blue', 1.0167991573999642),
#  ('jayspost', 1.0167991573999642),
#  ('401bravespost', 1.0167991573999642),
#  ('usmellfunny', 1.0167991573999642),
#  ('fightinforphilly', 1.0167991573999642),
#  ('mau5_419', 1.0167991573999642),
#  ('satiric', 1.0167991573999642),
#  ('thetb94', 1.0167991573999642),
#  ('girlfriend1521', 1.0167991573999642),
#  ('points1522', 1.0167991573999642),
#  ('points2010', 1.0167991573999642),
#  ('points2011', 1.0167991573999642),
#  ('vigorgaze', 1.0167991573999642),
#  ('mindslifedrinkermask', 1.0167991573999642),
#  ('fiendexpanded', 1.0167991573999642),
#  ('legop4o', 1.0167991573999642),
#  ('repertoire', 1.0167991573999642),
#  ('57752944', 1.0167991573999642),
#  ('timid', 1.0167774850156832),
#  ('points201', 1.0167540662740524),
#  ('180pouts', 1.0167373013244232),
#  ('searchlights', 1.0167090372135219),
#  ('agodragb', 1.0166965481831911),
#  ('eero', 1.0166488877777711),
#  ('yank', 1.0166260073078643),
#  ('avid', 1.0165853541359131),
#  ('sorgudadasdsac', 1.0165591763219537),
#  ('33commentslauren', 1.0165573011554354),
#  ('powershell', 1.016554018067809),
#  ('soothe', 1.016554018067809),
#  ('2fvi', 1.016554018067809),
#  ('freakincampers', 1.016554018067809),
#  ('negrodealma', 1.016554018067809),
#  ('netdecking', 1.016554018067809),
#  ('eltito666', 1.016554018067809),
#  ('67869350226e', 1.0165467633045535),
#  ('emg2101', 1.0165411613420994),
#  ('activity762763764when', 1.0165374213132521),
#  ('poop', 1.016475581592803),
#  ('cherokee', 1.0163733399064299),
#  ('eaterofdog', 1.0163565856032677),
#  ('anotherclumsyjawn', 1.0163521011375591),
#  ('points6532', 1.0163331764271606),
#  ('blocky', 1.0162844977205787),
#  ('zakke_', 1.0162753428191689),
#  ('hargleblargle', 1.0162599229715024),
#  ('2123', 1.0162460031131688),
#  ('endearing', 1.0162310937028911),
#  ('cs76', 1.0162283307232436),
#  ('shes', 1.016224302241058),
#  ('dignity', 1.0162209342540449),
#  ('weds', 1.0161125968750979),
#  ('httpauth', 1.0161057989311051),
#  ('177', 1.016105574206998),
#  ('seconds', 1.0161004898842818),
#  ('yogblert', 1.0160992560468398),
#  ('100mph', 1.0160660911549919),
#  ('000mha', 1.0160543808599887),
#  ('rpggeekhttps', 1.0160461394691478),
#  ('xrumrunnrx', 1.0160362726829735),
#  ('dustypigjut', 1.0160157946168622),
#  ('gws_rd', 1.0159552927222335),
#  ('housewives', 1.0159225076844354),
#  ('xuywhh', 1.0158669001466754),
#  ('theeriandus', 1.0158456288891027),
#  ('civs', 1.0158347879158904),
#  ('salto', 1.0158059214753212),
#  ('assimon', 1.0157989033635899),
#  ('d1rty_fucker', 1.0157946985561643),
#  ('configurable', 1.0157880221849522),
#  ('points980', 1.0157801004116036),
#  ('notifications7', 1.0157705804558435),
#  ('compliance', 1.0157530279468885),
#  ('shith_lard', 1.0157513078320117),
#  ('farmer', 1.0157181776986888),
#  ('truth', 1.0157117569380096),
#  ('327likeshow', 1.0156917673837882),
#  ('davidlaurilaqa', 1.0156822857056318),
#  ('monsterzero', 1.0156091590809391),
#  ('aonome', 1.015603652179575),
#  ('24000', 1.015585340776141),
#  ('overpopulation', 1.0155815246273687),
#  ('feeder', 1.0155643012970104),
#  ('moronic', 1.0155422459193013),
#  ('6p8vea', 1.0155330325442447),
#  ('blackwater', 1.0155072719820946),
#  ('agowuv', 1.0154964279454064),
#  ('steeek', 1.015481617707944),
#  ('filip3', 1.0154759097932118),
#  ('iterated', 1.0154752415579236),
#  ('underlearning', 1.0154690836368629),
#  ('grieve', 1.0154556140596482),
#  ('badparking', 1.0154508769798021),
#  ('hellfuzzy', 1.0154492629871519),
#  ('brightest', 1.0154185285830932),
#  ('kids1613', 1.0154066045219563),
#  ('roosevelt', 1.0154038828290541),
#  ('014418', 1.0154038442327047),
#  ('p194', 1.0153792359079556),
#  ('2242526an', 1.0153715608151055),
#  ('heartiest', 1.0153050501363792),
#  ('2454545464547', 1.0153024445970731),
#  ('rivets', 1.0152831935420321),
#  ('sixgunbuddyguy', 1.0152450405207669),
#  ('shadowmimik', 1.0152418038493487),
#  ('63rd', 1.0152296955765283),
#  ('4d', 1.015213475066751),
#  ('8798879897990floating', 1.0151986290569799),
#  ('storage', 1.0151919425561515),
#  ('looked', 1.0151823169886167),
#  ('righteousness', 1.015180016308054),
#  ('agoin', 1.0151622427188125),
#  ('zombie_jesus_', 1.0151536748485899),
#  ('libroscarica', 1.0151329355139884),
#  ('0trying', 1.0150967315325254),
#  ('userscripts', 1.015086232114371),
#  ('wallix', 1.0150559199877314),
#  ('john_barlycorn', 1.0149709851668234),
#  ('tw_raz', 1.0149632319181769),
#  ('points867', 1.0149476069385388),
#  ('3s3tmwffacq', 1.0149369886719384),
#  ('discussioncachedjul', 1.0149114750736952),
#  ('offarticle', 1.0148917925833025),
#  ('initiativesshare3685368', 1.014878745561224),
#  ('imbalances', 1.0148528878483667),
#  ('johnny_nofun', 1.0148528342144274),
#  ('alextootie', 1.0148528063215103),
#  ('substituting', 1.0148288507580607),
#  ('points2167', 1.0147838291929836),
#  ('points6814', 1.0147586427205686),
#  ('mbappe', 1.0146869484354595),
#  ('doctests', 1.0146661336886682),
#  ('coltsthecoltofpersonality', 1.0146380605826879),
#  ('vantaggioso', 1.0146241682267882),
#  ('castings', 1.0146224729534767),
#  ('formsminions', 1.0146005457812552),
#  ('blaaguuu', 1.0145846643746277),
#  ('0athletics435220', 1.014564518513084),
#  ('vasta', 1.0145505990635504),
#  ('17136206', 1.0145199167472934),
#  ('linkswikipedia', 1.0144556847758937),
#  ('get_dummies', 1.0143681679632601),
#  ('callmetmrw', 1.0143221952199937),
#  ('viralinfection', 1.0142938268145365),
#  ('emperorisnaked7', 1.0142932985515527),
#  ('crocs42', 1.0142772595255272),
#  ('ppr', 1.0142418267387097),
#  ('younew', 1.014226978388439),
#  ('754', 1.0142232623665628),
#  ('supersurg', 1.0141564304114192),
#  ('botnet', 1.014154210278164),
#  ('besttopnewcontroversialoldrandomq', 1.0141377137521621),
#  ('greatmorning', 1.0141162378557342),
#  ('aliases', 1.014095641863568),
#  ('keepin', 1.0140842312021121),
#  ('terrelle', 1.0140797157381698),
#  ('turf', 1.0140781141336701),
#  ('lachinio', 1.0140773101094338),
#  ('hol', 1.0140574415898012),
#  ('shaarj', 1.0140406556470756),
#  ('starbucks', 1.0140328529848832),
#  ('deevlix', 1.0140127368295306),
#  ('nivel', 1.0140024424146568),
#  ('lease', 1.0139376756135874),
#  ('nma', 1.013935733023789),
#  ('gross', 1.0139344856688821),
#  ('welcoming', 1.013922145323382),
#  ('2348005', 1.0139196564258146),
#  ('beraed', 1.0139196564258146),
#  ('erinpetenko', 1.0138193691142028),
#  ('07633', 1.0137993056405206),
#  ('points4940', 1.0137946009961878),
#  ('seakc87', 1.0137804157706887),
#  ('exogenous', 1.0137760681666832),
#  ('unremarkable', 1.0137742682250719),
#  ('tealcomet', 1.0137711687889563),
#  ('greengrinningjester', 1.0137597078272065),
#  ('uncomfortable', 1.013733219225448),
#  ('johnnygoodmeme', 1.0137187118952107),
#  ('krymz1n', 1.0137050406576467),
#  ('chincoteague', 1.0136777656311544),
#  ('ancestor', 1.0136532655220221),
#  ('hustle', 1.013640514420892),
#  ('critically', 1.0136171679196915),
#  ('settable', 1.0135994387915679),
#  ('smacksmackk', 1.0135994387915679),
#  ('6033', 1.0135994387915679),
#  ('quacktuary', 1.0135994387915679),
#  ('liverpoolihaverocketlegs', 1.0135994387915679),
#  ('falconstspitty', 1.0135976687414536),
#  ('norman', 1.013561598818119),
#  ('espositojoe', 1.013532413305549),
#  ('xbnm', 1.013520917432071),
#  ('blasting', 1.013500408521177),
#  ('tiltonarwhal', 1.0134831388763414),
#  ('detriment', 1.0134468005672765),
#  ('agosuch', 1.0134006279119412),
#  ('lionkingsongs', 1.0133551571299828),
#  ('screenwriter', 1.0133517007996562),
#  ('728', 1.0133358327372992),
#  ('predicated', 1.0133279608036279),
#  ('gretasgotagun', 1.0133014007718077),
#  ('requiem', 1.0132998679555185),
#  ('siouxsie_siouxv2', 1.0132605466915017),
#  ('0123456789', 1.0132302777043074),
#  ('transfers', 1.0131985280792208),
#  ('overtake', 1.0131687376757339),
#  ('conceived', 1.0131659627473184),
#  ('thats_what_me_said', 1.013159001863597),
#  ('subitles', 1.013139405560165),
#  ('faylom', 1.0131112342979867),
#  ('points41', 1.0130968844993233),
#  ('xpt', 1.0130893484803067),
#  ('fashionable', 1.0130589539801398),
#  ('cardinalswheelsmcgee28', 1.0130588366040403),
#  ('droettboom', 1.0130451504868609),
#  ('spawn2000', 1.0130089447815629),
#  ('r_and_dvc', 1.0129815326929796),
#  ('28000', 1.0129414160995378),
#  ('quad', 1.0129350651804001),
#  ('pydoubles', 1.0129338823911167),
#  ('legaladvice2', 1.0129008298481685),
#  ('solutiontagged', 1.0128832328411386),
#  ('elgeniodeldub', 1.0128679502122915),
#  ('ding', 1.0128562785748287),
#  ('fallenaege', 1.0128562785748287),
#  ('perloff', 1.0128305447469219),
#  ('polling', 1.0128256475316144),
#  ('whitman', 1.0128193739633637),
#  ('contractually', 1.0128182101199199),
#  ('ribosomaltransferrna', 1.0128014406241761),
#  ('incontinens', 1.0128006523250055),
#  ('harvesting', 1.0127670954853898),
#  ('bloodwork', 1.0127651213293669),
#  ('referencesarticles', 1.0127378139180057),
#  ('406188', 1.0127205961482935),
#  ('infusions', 1.0126770732457144),
#  ('zuperkamelen', 1.0126658646551625),
#  ('freeze', 1.0126561589220737),
#  ('responded', 1.0126561589220737),
#  ('afterlife', 1.0126561589220737),
#  ('296eric', 1.0126561589220737),
#  ('i_am_up_to_something', 1.0126497761091775),
#  ('cloaks', 1.0126453251868797),
#  ('chicken', 1.0126356777041512),
#  ('gvk8j0r', 1.0126064814538731),
#  ('jpicazo', 1.0125786793621006),
#  ('upor', 1.0125432131503278),
#  ('kalameloth', 1.0125127137523613),
#  ('2k28261223', 1.0124991334279434),
#  ('zach4science', 1.0124786669770844),
#  ('reactionscommentsharewusa', 1.0124686454254244),
#  ('borsboom', 1.0124636608809832),
#  ('zealots', 1.0124417724240582),
#  ('discussiongamespot', 1.0124407484880049),
#  ('cycles64193', 1.0124350873213275),
#  ('pacakges', 1.0124017418723421),
#  ('reasonably', 1.0124007558662864),
#  ('prob_buffer_row', 1.0124007558662864),
#  ('internet38', 1.0124007558662864),
#  ('youhannaei', 1.0124005022804179),
#  ('nikstick22', 1.0123931093218022),
#  ('reddit_exchangespromotedsavehidereporttrending', 1.0123833080236619),
#  ('oklajosha', 1.012379059698792),
#  ('terrifyingly', 1.012360992203619),
#  ('perleth', 1.0123563252018442),
#  ('bradford', 1.0123505503695573),
#  ('2uninstalling', 1.0123386517589337),
#  ('98demakemusic', 1.0122327124827404),
#  ('shifter', 1.0122026772571442),
#  ('concession', 1.0121929050869387),
#  ('𝟙𝟟𝟟𝟞', 1.0121922441356483),
#  ('bigsloppysunshine', 1.0121854060433366),
#  ('assertionerror', 1.0121837609690272),
#  ('theonlydjorkaeff1', 1.0121409951963944),
#  ('adaptability', 1.012119071772895),
#  ('25projection', 1.0120689884044543),
#  ('taydepenn', 1.0120669946983269),
#  ('syntax', 1.0120425994417743),
#  ('mkitch55', 1.012019798339284),
#  ('410maximus', 1.0120113373879049),
#  ('dragon109255', 1.0120092076255134),
#  ('chaz', 1.0120092076255134),
#  ('nightmarerift', 1.0120092076255134),
#  ('line_color', 1.0120092076255134),
#  ('smiles', 1.0120092076255134),
#  ('advertiser', 1.0120092076255134),
#  ('dettagli', 1.0119900040130947),
#  ('canals', 1.0119808720245271),
#  ('eh', 1.0119702111050204),
#  ('askwomen45', 1.0119397381524471),
#  ('definitelynotthatone', 1.0119385752826802),
#  ('phil1212121212', 1.0119106032678684),
#  ('dragonfire', 1.0118781221834126),
#  ('courtney', 1.0118654737005701),
#  ('jawa', 1.0118396033022654),
#  ('blackbeardsrevenge16', 1.0118283735850935),
#  ('el_wingador', 1.0118266569686116),
#  ('timothymodine', 1.0118090502569597),
#  ('cuntfirmed', 1.0118020970214141),
#  ('senoritaoscar', 1.0117569037049072),
#  ('0jquery', 1.0117448915901468),
#  ('mythological', 1.0117434601212849),
#  ('nafta', 1.0117215878357926),
#  ('filth', 1.0117083177981057),
#  ('bnetplayer', 1.0117050543644168),
#  ('adistron', 1.0117044954105112),
#  ('overwatchcomments', 1.0116590147335294),
#  ('6770184', 1.011645364874673),
#  ('superbanti', 1.0116044000543341),
#  ('whitewizardg', 1.0116004644120271),
#  ('shivers', 1.0115934414945569),
#  ('television', 1.0115886730337518),
#  ('prelude', 1.0115470398581776),
#  ('apex_pn01', 1.0115414051692078),
#  ('carthaginem', 1.0115278951479891),
#  ('938', 1.0114949059041956),
#  ('freelancing', 1.0114924978461546),
#  ('roaming', 1.0114886736402136),
#  ('pergamon', 1.0114818397545364),
#  ('soylentcolammgood', 1.0114703595575492),
#  ('output_file', 1.0114373843107185),
#  ('correlations', 1.0114330605247608),
#  ('napkins', 1.0114294878494841),
#  ('accounting', 1.0114238961631263),
#  ('opingtowardhatred', 1.0114132673706004),
#  ('offside', 1.0113666812149702),
#  ('falconsclassic1990', 1.0113562571220489),
#  ('4586', 1.0113439109565385),
#  ('basehttpserver', 1.0113408144666491),
#  ('supset', 1.0113390396764455),
#  ('incrementing', 1.0113379152575441),
#  ('listening_heads', 1.0113296656036959),
#  ('points664', 1.0113099186605667),
#  ('colby', 1.011308688549198),
#  ('wechat', 1.0112888105539621),
#  ('2016iam_dubstepit', 1.011283999976712),
#  ('geralt', 1.0112831454736619),
#  ('c643how', 1.0112317318351742),
#  ('gaphas', 1.0112263785740652),
#  ('esp', 1.0112258020162714),
#  ('violation', 1.0111770893438583),
#  ('asem', 1.0111437403175765),
#  ('averagelygreatnot', 1.0111314850728184),
#  ('bananastheleech', 1.0111098141774146),
#  ('17970', 1.0111004727986292),
#  ('buchrisricardo', 1.0110914999254466),
#  ('wmv', 1.0110695714460403),
#  ('goldbergs', 1.0110655709164509),
#  ('points203', 1.0110616338629137),
#  ('baseoement', 1.0110524668951923),
#  ('gui', 1.011039172921653),
#  ('decepticon', 1.0110390687586377),
#  ('clothing', 1.0110096037953131),
#  ('maneuvered', 1.0109923798203015),
#  ('theanoin', 1.0109639135099717),
#  ('harrasment', 1.010920745678467),
#  ('25auto1080p720p480p360p240pcaptionsmore', 1.0109192478840565),
#  ('spoiler238', 1.0109139452857465),
#  ('kajkia', 1.0109135707223846),
#  ('rcl2810', 1.0109036648947376),
#  ('commentsbroken', 1.0109034485997936),
#  ...]

# %%
# baseline
(y_train == 'procr').sum()/float(len(y_train))
# Out:
# 0.60030395136778114

# %%
sum(y_train == 'work')
# Out:
# 263

# %% [markdown]
# ### Analyzing Count vectorized results

# %%
temp = result_train[list(X_train.activity =='procr')]

# %%
X_train['python_count']  = list(result_train['python'])
# Out:
# /home/roland/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
temp = X_train[X_train.python_count > 0].sort_values('python_count', ascending = False)
list(temp[temp.activity == 'procr'].text)
# Out:
# 733     AnyDice            AnyDice Dice Probability C...
# 950                                                  ...
# Name: text, dtype: object

# %%
new_temp = pd.DataFrame(data=cvec.fit_transform(temp[temp.activity == 'procr'].iloc[0:2].text).todense(), columns=cvec.vocabulary_)

# %%
cvec.vocabulary_
# Out:
# {'anydice': 334,
#  'dice': 515,
#  'probability': 898,
#  'calculator': 408,
#  'articles': 343,
#  'stay': 1028,
#  'connected': 458,
#  'twitter': 1111,
#  'facebook': 589,
#  'google': 653,
#  'currently': 482,
#  'playing': 881,
#  'jasper': 717,
#  'flick': 609,
#  'output': 855,
#  '3d4': 174,
#  'view': 1140,
#  'data': 497,
#  'calculating': 407,
#  '92': 287,
#  '00': 0,
#  '42': 180,
#  '240': 126,
#  '250': 129,
#  '260': 133,
#  '270': 135,
#  '280': 139,
#  '290': 141,
#  '300': 143,
#  '310': 145,
#  '320': 150,
#  '330': 153,
#  '340': 156,
#  '350': 158,
#  '360': 162,
#  '370': 164,
#  '380': 166,
#  '390': 171,
#  '400': 176,
#  '410': 178,
#  '420': 181,
#  '430': 184,
#  '440': 186,
#  '450': 188,
#  '460': 190,
#  '470': 194,
#  '480': 196,
#  '490': 198,
#  '500': 202,
#  '510': 205,
#  '520': 206,
#  '530': 210,
#  '540': 214,
#  '550': 218,
#  '560': 220,
#  '570': 222,
#  '580': 225,
#  '590': 227,
#  '01': 3,
#  '600': 228,
#  '610': 230,
#  '02': 6,
#  '620': 231,
#  '630': 234,
#  '03': 7,
#  '640': 235,
#  '05': 9,
#  '650': 237,
#  '07': 14,
#  '660': 238,
#  '09': 16,
#  '670': 242,
#  '12': 45,
#  '680': 245,
#  '16': 102,
#  '690': 250,
#  '21': 119,
#  '700': 251,
#  '28': 138,
#  '710': 252,
#  '35': 157,
#  '720': 253,
#  '45': 187,
#  '730': 254,
#  '56': 219,
#  '740': 255,
#  '69': 249,
#  '750': 256,
#  '84': 271,
#  '761': 258,
#  '771': 259,
#  '781': 261,
#  '791': 262,
#  '65': 236,
#  '801': 264,
#  '90': 284,
#  '812': 267,
#  '822': 268,
#  '832': 269,
#  '842': 272,
#  '96': 296,
#  '853': 276,
#  '863': 277,
#  '873': 279,
#  '67': 241,
#  '883': 280,
#  '85': 274,
#  '894': 282,
#  '904': 285,
#  '914': 286,
#  '18': 109,
#  '924': 288,
#  '934': 290,
#  '944': 293,
#  '954': 295,
#  '963': 297,
#  '973': 298,
#  '983': 299,
#  '993': 300,
#  '1002': 18,
#  '1012': 20,
#  '1022': 22,
#  '1032': 24,
#  '1041': 26,
#  '1051': 29,
#  '1061': 30,
#  '1071': 31,
#  '1081': 32,
#  '1090': 33,
#  '1100': 35,
#  '1110': 36,
#  '1120': 37,
#  '1130': 38,
#  '1140': 39,
#  '1150': 40,
#  '1160': 41,
#  '1170': 42,
#  '1180': 43,
#  '1190': 44,
#  '1200': 46,
#  '1210': 47,
#  '1220': 48,
#  '1230': 49,
#  '1240': 53,
#  '1250': 54,
#  '1260': 55,
#  '1270': 56,
#  '1280': 57,
#  '1290': 59,
#  '1300': 62,
#  '1310': 63,
#  '1320': 65,
#  '1330': 66,
#  '1340': 67,
#  '1350': 68,
#  '1360': 69,
#  '1370': 70,
#  '1380': 71,
#  '1390': 72,
#  '1400': 74,
#  '1410': 75,
#  '1420': 77,
#  '1430': 79,
#  '1440': 80,
#  '1450': 82,
#  '1460': 83,
#  '1470': 84,
#  '1480': 85,
#  '1490': 86,
#  '1500': 88,
#  '1510': 89,
#  '1520': 90,
#  '1530': 92,
#  '1540': 94,
#  '1550': 95,
#  '1560': 96,
#  '1570': 98,
#  '1580': 99,
#  '1590': 101,
#  '1600': 103,
#  'chat': 429,
#  'creator': 475,
#  'using': 1126,
#  'widget': 1170,
#  'online': 851,
#  'willing': 1173,
#  'help': 675,
#  'understand': 1116,
#  'probabilities': 897,
#  'session': 985,
#  'remain': 936,
#  'alive': 322,
#  'hidden': 678,
#  'considered': 459,
#  'donating': 533,
#  'remind': 938,
#  'later': 752,
#  'yes': 1194,
#  'donated': 532,
#  'don': 531,
#  'bother': 385,
#  'geekandsundry': 639,
#  'twitch': 1109,
#  'language': 747,
#  'dansk': 493,
#  'deutsch': 509,
#  'english': 566,
#  'uk': 1113,
#  'español': 584,
#  'españa': 583,
#  'latinoamérica': 753,
#  'français': 624,
#  'italiano': 712,
#  'magyar': 778,
#  'nederlands': 831,
#  'norsk': 841,
#  'polski': 886,
#  'português': 889,
#  'brasil': 389,
#  'slovenčina': 1005,
#  'suomi': 1046,
#  'svenska': 1050,
#  'tiếng': 1086,
#  'việt': 1143,
#  'türkçe': 1112,
#  'čeština': 1198,
#  'ελληνικά': 1199,
#  'български': 1200,
#  'русский': 1201,
#  'العربية': 1202,
#  'ภาษาไทย': 1203,
#  '中文': 1204,
#  '简体': 1206,
#  '繁體': 1207,
#  '日本語': 1205,
#  '한국어': 1208,
#  'img': 700,
#  'src': 1024,
#  'scorecardresearch': 973,
#  'com': 454,
#  'c1': 403,
#  'amp': 329,
#  'c2': 404,
#  '6745306': 244,
#  'c3': 405,
#  'c5': 406,
#  'cj': 438,
#  'href': 692,
#  'www': 1188,
#  'quantcast': 907,
#  '16unvwiygowyg': 105,
#  'target': 1058,
#  '_blank': 301,
#  'alt': 324,
#  'border': 383,
#  'height': 673,
#  'pixel': 873,
#  'quantserve': 908,
#  'gif': 643,
#  'style': 1038,
#  'display': 522,
#  'width': 1171,
#  'following': 614,
#  'browse': 396,
#  'mobile': 817,
#  'ad': 310,
#  'choices': 433,
#  'advertisers': 314,
#  'blog': 375,
#  'creative': 474,
#  'cookie': 465,
#  'policy': 885,
#  'developers': 510,
#  'jobs': 721,
#  'music': 826,
#  'partners': 860,
#  'press': 894,
#  'privacy': 896,
#  'store': 1032,
#  'terms': 1062,
#  'desktop': 508,
#  'app': 336,
#  'prime': 895,
#  'loot': 771,
#  'notifications': 843,
#  'mark': 787,
#  'read': 918,
#  'friend': 627,
#  'requests': 943,
#  'pending': 867,
#  'recent': 926,
#  'dahiceman': 485,
#  'invisible': 709,
#  'share': 992,
#  'activity': 309,
#  'watching': 1155,
#  'streaming': 1036,
#  'friends': 628,
#  'channel': 425,
#  'video': 1138,
#  'manager': 783,
#  'dashboard': 496,
#  'messages': 803,
#  'subscriptions': 1043,
#  'inventory': 708,
#  'settings': 987,
#  'log': 768,
#  'hide': 679,
#  'verified': 1135,
#  'videos': 1139,
#  '214': 121,
#  'clips': 441,
#  'collections': 452,
#  'events': 585,
#  'followers': 613,
#  '323': 151,
#  '313': 148,
#  '51': 204,
#  'enjoying': 568,
#  'stream': 1035,
#  'add': 311,
#  'directory': 519,
#  'live': 764,
#  'dismiss': 521,
#  'receive': 925,
#  'updates': 1120,
#  'including': 701,
#  'upload': 1122,
#  'email': 559,
#  'web': 1159,
#  'subscribe': 1041,
#  'rebroadcast': 922,
#  'critical': 477,
#  'role': 949,
#  'ep105': 573,
#  'obnoxious': 846,
#  'gnslive': 649,
#  'voxmachina': 1146,
#  'specialguest': 1016,
#  'welovedarin': 1164,
#  '13': 61,
#  'days': 500,
#  'ago': 316,
#  'dungeons': 546,
#  'dragons': 542,
#  '32': 149,
#  '213': 120,
#  'total': 1094,
#  'views': 1142,
#  'vk': 1144,
#  'reddit': 929,
#  'copy': 467,
#  'clipboard': 440,
#  'link': 762,
#  'embed': 560,
#  'report': 942,
#  '850': 275,
#  '23': 124,
#  '53': 209,
#  'axyb': 356,
#  'continuing': 461,
#  'adventures': 313,
#  'guardians': 661,
#  'galaxy': 636,
#  '15': 87,
#  'hours': 689,
#  '251': 130,
#  '29': 140,
#  '26': 132,
#  'telltale': 1060,
#  '17': 106,
#  '143': 78,
#  '47': 193,
#  'game': 637,
#  'engine': 565,
#  'talking': 1056,
#  'castlevania': 420,
#  'exec': 588,
#  'prod': 900,
#  'adi': 312,
#  'shankar': 991,
#  'ready': 919,
#  'player': 879,
#  'cast': 419,
#  'bet': 369,
#  'joins': 723,
#  '664': 239,
#  '11': 34,
#  '39': 170,
#  'talks': 1057,
#  'machina': 776,
#  'dark': 495,
#  '839': 270,
#  'broadcast': 393,
#  'sdcc': 975,
#  'panel': 857,
#  '19': 111,
#  '132': 64,
#  '22': 122,
#  '019': 5,
#  '59': 226,
#  '25': 128,
#  'int': 705,
#  'writers': 1186,
#  'room': 956,
#  'ep3': 577,
#  'person': 871,
#  'conversation': 463,
#  'writewithus': 1187,
#  'davetherevolution': 499,
#  'jul': 725,
#  '24': 125,
#  '2017': 115,
#  '205': 117,
#  'vast': 1132,
#  's1': 962,
#  'ep12': 575,
#  'finale': 600,
#  'pt': 903,
#  'truth': 1106,
#  'finaleps': 601,
#  '78': 260,
#  '621': 232,
#  'shield': 993,
#  'tomorrow': 1089,
#  'pull': 904,
#  '20': 113,
#  '869': 278,
#  '46': 189,
#  '43': 183,
#  'wednesday': 1160,
#  'club': 445,
#  'comic': 456,
#  'special': 1015,
#  'guest': 662,
#  'host': 687,
#  'erika': 580,
#  'ishii': 710,
#  '414': 179,
#  '58': 224,
#  'mines': 811,
#  'crafts': 469,
#  'minecraft': 810,
#  'dragon': 540,
#  'wall': 1150,
#  'scupture': 974,
#  '392': 172,
#  '37': 163,
#  '31': 144,
#  'trek': 1102,
#  'creamsoda': 472,
#  '940': 292,
#  'dallensday': 487,
#  '534': 212,
#  'roundtable': 958,
#  'e3': 550,
#  'bonus': 380,
#  'fun': 632,
#  'enjoy': 567,
#  '209': 118,
#  '14': 73,
#  '064': 12,
#  '33': 152,
#  'oopsibrokesomeglasses': 853,
#  '466': 192,
#  'diablo3': 514,
#  'necromancer': 830,
#  'cm': 449,
#  'diablo': 513,
#  'brandy': 388,
#  'camel': 410,
#  '505': 203,
#  'discussing': 520,
#  'episode': 578,
#  '105': 28,
#  '271': 136,
#  '04': 8,
#  '49': 197,
#  'flip': 610,
#  'squad': 1022,
#  'cam': 409,
#  'alex': 320,
#  'elizabeth': 557,
#  '172': 108,
#  '08': 15,
#  'ep2': 576,
#  'single': 999,
#  'talent': 1054,
#  'stories': 1033,
#  '381': 167,
#  '40': 175,
#  'ep11': 574,
#  'links': 763,
#  'amanda': 326,
#  'powers': 891,
#  'gina': 645,
#  'devivo': 512,
#  'jeff': 719,
#  'torres': 1093,
#  'amy': 331,
#  'dallen': 486,
#  'dylan': 547,
#  'dovale': 538,
#  'jackson': 715,
#  'lanzing': 749,
#  'pac': 856,
#  'ha': 666,
#  '145': 81,
#  '10': 17,
#  '757': 257,
#  'shows': 997,
#  'week': 1161,
#  'things': 1075,
#  'great': 657,
#  'weekend': 1162,
#  '55': 217,
#  '153': 91,
#  '154': 93,
#  '30': 142,
#  '683': 246,
#  'gather': 638,
#  'party': 861,
#  'josephine': 724,
#  'hosts': 688,
#  'becca': 368,
#  'sketch': 1001,
#  'team': 1059,
#  'dr': 539,
#  'america': 328,
#  'performs': 870,
#  'dance': 489,
#  '274': 137,
#  '44': 185,
#  '012': 4,
#  '54': 213,
#  '50': 201,
#  'brick': 391,
#  'battles': 365,
#  'tower': 1095,
#  'defense': 507,
#  'welcome': 1163,
#  'metaria': 805,
#  'ii': 697,
#  'featuring': 596,
#  'kate': 733,
#  'vs': 1147,
#  'trisha': 1104,
#  '142': 76,
#  'valerian': 1128,
#  'alpha': 323,
#  'missions': 816,
#  'world': 1182,
#  'exclusive': 587,
#  '171': 107,
#  'bits': 373,
#  'cheer': 430,
#  '63': 233,
#  'play': 877,
#  '227': 123,
#  '38': 165,
#  'neverbeenseen': 834,
#  '671': 243,
#  'friday': 626,
#  '244': 127,
#  'thursday': 1080,
#  'mothership': 822,
#  '331': 154,
#  '947': 294,
#  '27': 134,
#  '129': 58,
#  'chobot': 432,
#  'hector': 672,
#  'thrones': 1079,
#  'recap': 924,
#  'learn': 755,
#  'speak': 1014,
#  'dothraki': 537,
#  'mass': 790,
#  'debate': 504,
#  'got': 654,
#  'shame': 990,
#  'death': 503,
#  'squared': 1023,
#  'speedrunning': 1017,
#  '668': 240,
#  'promos': 902,
#  'july': 726,
#  '528': 207,
#  '491': 199,
#  '93': 289,
#  '94': 291,
#  'minute': 812,
#  'topic': 1092,
#  'talk': 1055,
#  '157': 97,
#  '311': 146,
#  '541': 215,
#  '461': 191,
#  '48': 195,
#  'secret': 979,
#  'headquarters': 670,
#  '891': 281,
#  'marisha': 786,
#  'ray': 915,
#  'shirt': 994,
#  'rebuilding': 923,
#  'create': 473,
#  'clothing': 444,
#  '808': 265,
#  '687': 248,
#  '399': 173,
#  'e2': 549,
#  '180': 110,
#  'dms': 527,
#  'tips': 1083,
#  '194': 112,
#  'marvel': 788,
#  'series': 983,
#  '252': 131,
#  '41': 177,
#  'distractions': 524,
#  '123456789101112': 51,
#  'related': 934,
#  '604': 229,
#  '103': 23,
#  '104': 25,
#  'sorrytravis': 1012,
#  'justin': 730,
#  'roiland': 948,
#  'anatomy': 332,
#  'park': 859,
#  'card': 417,
#  'jun': 727,
#  '34': 155,
#  '065': 13,
#  '104b': 27,
#  'elysium': 558,
#  'ep104': 572,
#  '312': 147,
#  'camera': 411,
#  'action': 308,
#  '4pm': 200,
#  'dnd': 528,
#  '060': 11,
#  '57': 221,
#  '421': 182,
#  'meet': 799,
#  'crew': 476,
#  'uss': 1127,
#  'sally': 965,
#  'ride': 945,
#  '1234': 50,
#  'popular': 888,
#  '164': 104,
#  'house': 690,
#  'wins': 1176,
#  'e19': 548,
#  'acquisitions': 306,
#  'pennyarcade': 868,
#  'high': 680,
#  'rollers': 950,
#  'uncharted': 1115,
#  'territory': 1063,
#  'yogscast': 1195,
#  '529': 208,
#  '101': 19,
#  'unexpectables': 1117,
#  'takahata101': 1053,
#  'rollplay': 951,
#  'court': 468,
#  'swords': 1051,
#  'king': 739,
#  'patreon': 862,
#  'rollplaystore': 952,
#  'dansgaming': 492,
#  'cinnamontoastk': 435,
#  'annemunition': 333,
#  'skinnyghost': 1002,
#  'itmejp': 713,
#  '386': 168,
#  '36': 161,
#  'wide': 1169,
#  'wrestling': 1185,
#  'commanderholly': 457,
#  'britweisman': 392,
#  'bluejay_712': 377,
#  'distractedelf': 523,
#  '12pm': 60,
#  '7pm': 263,
#  '848': 273,
#  'sound': 1013,
#  'test': 1064,
#  'charisma': 428,
#  'plus': 882,
#  'cinnamontoastken': 436,
#  '811': 266,
#  'frozen': 630,
#  'frontier': 629,
#  '007': 2,
#  'cold': 450,
#  'snap': 1007,
#  'koibu': 743,
#  '686': 247,
#  'roobventure': 954,
#  'shadow': 988,
#  'assailants': 346,
#  'warpedlamp': 1153,
#  '571': 223,
#  'fantasy': 591,
#  'campaign': 412,
#  '542': 216,
#  'skywatch': 1004,
#  'green': 658,
#  'ronin': 953,
#  'age': 315,
#  'yt': 1196,
#  'hyperrpg': 695,
#  '532': 211,
#  'indomitable': 703,
#  'season': 977,
#  'tmnt': 1087,
#  'valiant': 1129,
#  'vanquished': 1131,
#  'volume': 1145,
#  'issue': 711,
#  '387': 169,
#  '359': 160,
#  'misscliks': 815,
#  '353': 159,
#  'maze': 795,
#  'arcana': 338,
#  'fury': 634,
#  'reach': 917,
#  'based': 364,
#  'viewing': 1141,
#  'history': 682,
#  'remove': 939,
#  'recommendation': 927,
#  '897': 283,
#  'ep103': 571,
#  'conundrum': 462,
#  'criticalrole': 478,
#  'happybirthdaymattmercer': 668,
#  'ep102': 570,
#  'thar': 1067,
#  'amphala': 330,
#  '159': 100,
#  '102': 21,
#  'broadcaster': 394,
#  'indicated': 702,
#  'intended': 706,
#  'mature': 793,
#  'audiences': 348,
#  'start': 1026,
#  'content': 460,
#  'enter': 569,
#  'date': 498,
#  'birth': 371,
#  'sorry': 1011,
#  'january': 716,
#  'february': 597,
#  'march': 785,
#  'april': 337,
#  'june': 728,
#  'august': 349,
#  'september': 982,
#  'october': 847,
#  'november': 844,
#  'december': 505,
#  '12345678910111213141516171819202122232425262728293031': 52,
#  '...': 116,
#  'submit': 1040,
#  'nextwatch': 835,
#  'cancelmore': 413,
#  'device': 511,
#  'geekandsundryrebroadcast': 640,
#  'minutes': 813,
#  'automatically': 351,
#  'reload': 935,
#  'error': 581,
#  'closed': 443,
#  'caption': 416,
#  'presets': 893,
#  'text': 1065,
#  'effects': 553,
#  'background': 359,
#  'window': 1174,
#  'aa': 302,
#  'font': 615,
#  'mono': 819,
#  'serif': 984,
#  'sans': 968,
#  'casual': 421,
#  'cursive': 483,
#  'small': 1006,
#  'capitals': 415,
#  'alignment': 321,
#  'left': 756,
#  'center': 423,
#  'right': 946,
#  'color': 453,
#  'position': 890,
#  'opacity': 854,
#  'solid': 1009,
#  'translucent': 1096,
#  'semi': 980,
#  'transparent': 1097,
#  'flashing': 608,
#  'size': 1000,
#  'effect': 552,
#  '0004': 1,
#  'supports': 1048,
#  'resolution': 944,
#  'fps': 622,
#  'skipped': 1003,
#  'frames': 623,
#  'buffer': 399,
#  'sec': 978,
#  'latency': 751,
#  'encoder': 563,
#  'playback': 878,
#  'rate': 914,
#  'kbps': 734,
#  'memory': 801,
#  'usage': 1124,
#  'backend': 358,
#  'version': 1136,
#  'whispers': 1167,
#  'enable': 562,
#  'disturb': 525,
#  'people': 869,
#  'close': 442,
#  'replay': 941,
#  '06': 10,
#  'ikilledthebalrog': 698,
#  'oh': 850,
#  'sam': 966,
#  'da': 484,
#  'danh': 490,
#  'supergamesniper9': 1047,
#  'getting': 641,
#  'cooked': 464,
#  'reinhart': 932,
#  'kennyzedevildog96': 735,
#  'dubbomale': 545,
#  'thegalacticowl': 1074,
#  'bahm': 360,
#  'beartrap': 367,
#  'tijogar': 1082,
#  'firestorm': 604,
#  'major': 779,
#  'blaze': 374,
#  'flashes': 607,
#  'burning': 402,
#  'starting': 1027,
#  'easily': 551,
#  'level': 757,
#  'spell': 1018,
#  'sean_png': 976,
#  'dd': 501,
#  'bear': 366,
#  'trap': 1098,
#  'bowtiefox': 387,
#  'thats': 1068,
#  'way': 1158,
#  'guy': 664,
#  'spread': 1020,
#  'wings': 1175,
#  'maximuskane8222': 794,
#  'ehhhh': 554,
#  'gilgamesh_prime': 644,
#  'worse': 1184,
#  'foresight': 617,
#  'keyleth': 737,
#  'cersei': 424,
#  'lannister': 748,
#  'womstv': 1178,
#  'twitchprime': 1110,
#  'nightbot': 837,
#  'amazon': 327,
#  'account': 303,
#  'gives': 646,
#  'free': 625,
#  'subscription': 1042,
#  'cool': 466,
#  'stuff': 1037,
#  'month': 820,
#  'use': 1125,
#  'http': 693,
#  'bit': 372,
#  'ly': 774,
#  'howtosubwithtwitchprime': 691,
#  'remember': 937,
#  'need': 832,
#  'manually': 784,
#  'renewed': 940,
#  'mrny2cali': 824,
#  'traps': 1099,
#  'whatchamccollum': 1166,
#  'damages': 488,
#  'objects': 845,
#  'area': 339,
#  'ignites': 696,
#  'flammable': 606,
#  'aren': 340,
#  'worn': 1183,
#  'carried': 418,
#  'choose': 434,
#  'plant': 875,
#  'life': 759,
#  'unaffected': 1114,
#  'guys': 665,
#  'masonraburn': 789,
#  'nightraver01': 838,
#  'thacod20': 1066,
#  'said': 963,
#  'just': 729,
#  'went': 1165,
#  'firestarter': 603,
#  'mcjenn': 796,
#  'mean': 797,
#  'like': 760,
#  'needs': 833,
#  'anymore': 335,
#  'vecna': 1134,
#  'knows': 742,
#  'living': 765,
#  'lmfao': 767,
#  'dragonchrome': 541,
#  'hi': 677,
#  'bskrueger': 397,
#  'clutchcritter': 448,
#  'nice': 836,
#  'brenfast': 390,
#  'crap': 470,
#  'muntface': 825,
#  'feelsbadman': 598,
#  'hey': 676,
#  'valkata2200': 1130,
#  'greywindvii': 659,
#  'glad': 647,
#  'knew': 741,
#  'meme': 800,
#  'wyvernsforhands': 1189,
#  'favored': 595,
#  'enemy': 564,
#  'elderly': 555,
#  'sprigg': 1021,
#  'doomed': 536,
#  'troubleman72': 1105,
#  'attack': 347,
#  'titan': 1084,
#  'reference': 931,
#  'michaelkris': 807,
#  'the_ark_angels': 1069,
#  'lmao': 766,
#  'going': 651,
#  'funny': 633,
#  'pyrotechnick777': 906,
#  'kitchen': 740,
#  'fiyah': 605,
#  'altex8': 325,
#  'sandmaviper': 967,
#  'roof': 955,
#  'wallflowerkit': 1151,
#  'holy': 683,
#  'shit': 995,
#  'ashley': 344,
#  'johnson': 722,
#  'csi': 481,
#  'raymusrtic': 916,
#  'snarkyrogue': 1008,
#  'scanlan': 972,
#  'pulled': 905,
#  'suppose': 1049,
#  'm27aust': 775,
#  'sailorjay42': 964,
#  'jmatthews85': 720,
#  'crossfire1776': 480,
#  'trees': 1101,
#  'peanutspack': 865,
#  'fan': 590,
#  'art': 342,
#  'babycato': 357,
#  'ooooohhhh': 852,
#  'burn': 401,
#  'thecriticalhit': 1070,
#  'fine': 602,
#  'bogardd': 378,
#  'kuyogre': 746,
#  'make': 780,
#  'kiki': 738,
#  'lucifermoloch': 773,
#  'spiritpotatoh': 1019,
#  'guiding': 663,
#  'bolt': 379,
#  'classic': 439,
#  'dannyphantom84': 491,
#  'dregor319': 543,
#  'hopefully': 686,
#  ...}

# %%
list(temp[temp.activity == 'procr'].iloc[0:1].text)
# Out:
# [" AnyDice            AnyDice Dice Probability Calculator   Articles      Stay Connected  Twitter,     Facebook,     Google+  Currently Playing     made by Jasper Flick     output 3d4   View       Data       ...calculating...   output 1 (92.00 / 9.42)#%240.00\xa0250.00\xa0260.00\xa0270.00\xa0280.00\xa0290.00\xa0300.00\xa0310.00\xa0320.00\xa0330.00\xa0340.00\xa0350.00\xa0360.00\xa0370.00\xa0380.00\xa0390.00\xa0400.00\xa0410.00\xa0420.00\xa0430.00\xa0440.00\xa0450.00\xa0460.00\xa0470.00\xa0480.00\xa0490.00\xa0500.00\xa0510.00\xa0520.00\xa0530.00\xa0540.00\xa0550.00\xa0560.00\xa0570.00\xa0580.00\xa0590.01\xa0600.01\xa0610.02\xa0620.02\xa0630.03\xa0640.05\xa0650.07\xa0660.09\xa0670.12\xa0680.16\xa0690.21\xa0700.28\xa0710.35\xa0720.45\xa0730.56\xa0740.69\xa0750.84\xa0761.01\xa0771.21\xa0781.42\xa0791.65\xa0801.90\xa0812.16\xa0822.42\xa0832.69\xa0842.96\xa0853.21\xa0863.45\xa0873.67\xa0883.85\xa0894.00\xa0904.12\xa0914.18\xa0924.21\xa0934.18\xa0944.12\xa0954.00\xa0963.85\xa0973.67\xa0983.45\xa0993.21\xa01002.96\xa01012.69\xa01022.42\xa01032.16\xa01041.90\xa01051.65\xa01061.42\xa01071.21\xa01081.01\xa01090.84\xa01100.69\xa01110.56\xa01120.45\xa01130.35\xa01140.28\xa01150.21\xa01160.16\xa01170.12\xa01180.09\xa01190.07\xa01200.05\xa01210.03\xa01220.02\xa01230.02\xa01240.01\xa01250.01\xa01260.00\xa01270.00\xa01280.00\xa01290.00\xa01300.00\xa01310.00\xa01320.00\xa01330.00\xa01340.00\xa01350.00\xa01360.00\xa01370.00\xa01380.00\xa01390.00\xa01400.00\xa01410.00\xa01420.00\xa01430.00\xa01440.00\xa01450.00\xa01460.00\xa01470.00\xa01480.00\xa01490.00\xa01500.00\xa01510.00\xa01520.00\xa01530.00\xa01540.00\xa01550.00\xa01560.00\xa01570.00\xa01580.00\xa01590.00\xa01600.00\xa0              You can chat with me – the creator of AnyDice – using the widget below, if I'm online. I am willing to help you with AnyDice. I can also help you understand dice probabilities.     The chat session will remain alive even when it is hidden.           Have you considered donating?    Show me how and why! Remind me later. Yes, I have already donated! No, and don't bother me again!  "]
